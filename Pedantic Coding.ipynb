# %% [markdown]
# # Propositional Logic
#
#
# This code activity will try to guide you in applying the concepts, methods, and appplications of Propositional Logic through code. We will go through with the algorithms used to dervide Propositional Logic , and then we will try to look at a practical example through a user's requirement.

# %% [markdown]
# # Implication
# Starting with implication would make explaining propositional logic in code.
#
# Normally, we express implication or the conditional statement as $p$ implies $q$ with the logical connective $\rightarrow$. In code, the antecedent $p$ or the premise serves as the condition argument and sometimes the parameter while the consequent $q$ is the resulting action given the condition. We formally denote this as:
#
# $$p\rightarrow q$$
# We can also visualize this using a flowchart so it can be easily implemented as an algorithm.

# %%
from PIL import Image
img = Image.open('if.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=240x580 at 0x225B20944F0>

# %% [markdown]
# As an example, we are given a statement:
#
# It can then be coded as such:

# %%
isDetected = False
if (isDetected):
    print("Turning lights on.")

# %% [markdown]
# However, when talking about conditions it is natural to add the else clause or the negative consequent. The else statement or clause can be phrased as: if not $q$ then $r$. Although the opposite reaction will be observed as the alternative consequent of $\neg p$ it is not the same as the negation of $\neg q$, thus it is translated as a different event $r$. It can then have the wff as:
#
# $$(p\rightarrow q)  \land (\neg p \rightarrow r) $$
# And for it's flowchart:

# %%
from PIL import Image
img = Image.open('else.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=560x538 at 0x225B1F194F0>

# %% [markdown]
# We can also modifying the previous statement as:
#
# We can then code this as:

# %% [markdown]
# if (isDetected):
#     print("Turning lights on.")
# else:
#     print("Turning lights off.")

# %% [markdown]
#  The third case of implications in programming is the appearance of a third or nth condition. In other programming languages thise can be in the form of cases switch statements or else if statements, but for Python it is implemented as elif. The elif statement or any other additional statement can be interjected into the if..else statement as a nestedimplication $a\rightarrow b$ and its alternative consequent. We can then restructure the wff as:
#
# $$(p\rightarrow q) \land  (\neg p \rightarrow ((a \rightarrow b) \land (\neg a \rightarrow b))) $$
# Visualizing the wff:

# %%
from PIL import Image
img = Image.open('elif.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=560x778 at 0x225B1DF3220>

# %% [markdown]
# We can then thry to increase the number of cases of the previous statement:
#
# Then we can code it as:

# %%
detection_value = 1
if (detection_value == 0):
    print("Turning lights on (slightly).")
elif (detection_value == 1):
    print("Turning lights on (to the max!).")
else:
    print("Turning lights off.")
# Out:
# Turning lights on (to the max!).

# %% [markdown]
# # Disjunction
# In contrast with natural language and conversational English that assumes that the "or" logical connective is Exclusive, programming logic treats the "or" logical connective as an Inclusive Disjunction operation. Disjunction operations require at least two arguments or premises, we can denote them as $p$ and $q$ again and we use the $\lor$ logical connective. We could then write the wff as:
#
# $$p\lor q$$
# So given that we integrate our disjunction in a conditional statement $(p \lor q) \rightarrow r$, the flowchart will be:

# %%
from PIL import Image
img = Image.open('or.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=240x518 at 0x225B1E82A00>

# %% [markdown]
# Let's try to analyze the following statement:

# %%
selected_optin = True
location = 'Canada'
if (selected_optin or location == 'Philippines'):
    print('Succesfully sent a newsletter invite.')

# %% [markdown]
# # Conjunction
# The last connective we will address in this module is the conjuction or the "and" operator. Conjunction operations require at least two arguments or premises, we can denote them as $p$ and $q$ again and we use the $\land$ logical connective. We could then write the wff as:
#
# $$p\land q$$
#
#
# And with a flowchart as:

# %%
from PIL import Image
img = Image.open('an.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=320x518 at 0x225B1E3B670>

# %% [markdown]
# Consider the statement below:
#
# We can code this as

# %%
has_mask = True
has_shades = False
if (has_mask and has_shades):
    print("Sounding the alarm.")

# %% [markdown]
# You might have noticed in the implications section we have not encountered a nested-if statement. I would like to show a trick regarding that, but it would require discussing conjunctions first. So let's say we have this flowchart:

# %%
from PIL import Image
img = Image.open('nest.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=235x718 at 0x225B2094CA0>

# %% [markdown]
# You might be more familiar with it's code form as:

# %%
p,q = True, False
if (p):
    if (q):
        print(True)
else:
    print(False)

# %% [markdown]
# This can be further simplified as shown below:

# %%
from PIL import Image
img = Image.open('simp.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=660x718 at 0x225B1F19FD0>

# %% [markdown]
# If you like proofs here's how it was derived:
#
# Given wff: $p \rightarrow (q\rightarrow r)$
#
# $ = \neg p \lor (q\rightarrow r) : $ Definition of implication
#
# $ = \neg p \lor (\neg q \lor r) : $ Definition of implication
#
# $ = (\neg p \lor \neg q)\lor r : $ Associative Rule
#
# $ = \neg(p \land q)\lor r : $ De Morgan's Law
#
# $ = (p \land q)\rightarrow r : $ Definition of implication

# %% [markdown]
# # Activities

# %% [markdown]
# '''
# ACTIVITY 1 (50 points)
#
# You will be given either a statement or a formula as your activity. If you are given a formula please translate them into an English statement,
# however, if you are given an English statement translate them to a wff. For both cases provide the code below, then run it to display the output.
# '''
#
# Given the English statement:
#
#
#
# Ask for additional fries and drinks to the order if the customer would buy a Cheese Burger Deluxe but add a Sundae instead if they do not. Always remember to print the receipt for every transaction.
#
#
#
# Formulate the well-formed formulas, the flowchart, and the corresponding code. You may paste your GitHub link or a Google drive link or upload a compressed file as your submission.
#
#
# ### START YOUR CODE BELOW HERE ###
#
#
#
# ### END OF CODE ###

# %%
from PIL import Image
img = Image.open('.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1277x632 at 0x225B1F191C0>

# %%
fries_and_drinks = True
sundae = False

y = fries_and_drinks
x = sundae

if(y):
    print("Cheese Burger Deluxe with Fries and Drinks")
elif(x):
    Print("Cheese Burger Deluxe with sundae")
else:
    print("Cheese Burger Deluxe ")
# Out:
# Cheese Burger Deluxe with Fries and Drinks

# %% [markdown]
# '''
# ACTIVITY 2 (50 points)
#
# Given the pseudocode provided to you determine the WFF and English statement. For additional points (equivalent to 2 points), derive the simplified
# flowchart and WFF for the given pseudocode.
# '''
#
#
# ### START YOUR CODE BELOW HERE ###
#
#
#
# ### END OF CODE ###
#
# Given the pseudocode:

# %%
def transfer_to_resource(reservoir, pool):

if pool <= 10 and reservoir > 20:
pool = reservoir


return pool
# Out:
#   File "<ipython-input-8-fd02dd342ea6>", line 1
#     def transfer_to_resource(reservoir, pool)
#                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# Determine the WFFs and decode it to its original English statement. Use the math formula in the text editor. WFFs that will not use the math formula feature will not be credited. Refrain from using (^ , v, ~ ).

# %%
from PIL import Image
img = Image.open('flowchart2.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1159x576 at 0x225B2094A00>

# %% [markdown]
# # Scratch Area
#
# You can use the area below to try your own code.
